# %% [markdown]
# <a href="https://colab.research.google.com/github/nickkraus52/MachineLearning/blob/main/HW2/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets?
# One thing I noticed that was different was slight inconsistances in data imput. For browser types there was many entries set to unkown instead of nan. There was also an unecessary session ID column which. These qualities both go to show the difference between a raw external dataset and an already cleaned up pre-packaged dataset.
#
# ## How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose?
# I initially used isnull().sum() to determine encryption_used had 1966 missing entries. I used imputation for these entries and set them to "None", and no other columns needed imputation. I noticed that session_id was unique and not necessary, so I furthered cleaned the data by dropping the column.
#
# ## Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across preprocessing steps.
# The column transformer and pipeline are very useful because they combine and automate the scaling for numerical data and the encoding for categorical data. It makes things easier and deceases room for error. It prevents data leakage because when the pipeline is called with .fit() it only makes evaluations on the training data. When transform is called it reuses those statistics it already created instead of recomputing with testing data.
#
# ## Based on your correlation matrix and heatmap, which features show the strongest relationships with the target variable (attack_detected), and what operational insights do these relationships reveal?
# Failed logins, login attempts, and IP reputation score all seemed significantly more important than the other factors. I would say this advocates for stronger log in attempt and failed log in attempt detection and prevention. Also some type of firewall that prevents traffic from IP addresses with a reputation passed a certain threshold may be a very beneficial safety measure.
