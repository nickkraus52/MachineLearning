# %% [markdown]
# <a href="https://colab.research.google.com/github/nickkraus52/MachineLearning/blob/main/HW1/01_Python_Essentials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 10
other = 5
name = 'Joe'
print(num, other, name)

# %%
salary = 70000
job = 'Data Scientist'
print(salary)
print(job)

# %% [markdown]
# # Lists

# %%
Heights = [70, 65, 68, 71, 74]
average_height = sum(Heights) / len(Heights)
print(average_height)

# %% [markdown]
# # Dictionaries

# %%
grade_dictionary = {"Joe" : 3.2, "Doug" : 2.8, "Mat" : 4.0}
for key, value in grade_dictionary.items():
    print(key, value)

print(grade_dictionary["Joe"]) # Prints 3.2

# %% [markdown]
# # Functions

# %%
def absolute(num):
    if num < 0:
        return num * -1
    else:
        return num

num = absolute(-5)
print(num) # Prints 5
