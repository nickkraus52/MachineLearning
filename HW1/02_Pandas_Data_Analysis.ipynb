# %% [markdown]
# <a href="https://colab.research.google.com/github/nickkraus52/MachineLearning/blob/main/HW1/02_Pandas_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = 10
print(word)
# Out:
# 10
